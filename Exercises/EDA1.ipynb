# %% [markdown]
# #### Importing libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #### Loading the datasets into pandas dataframe

# %%
data = pd.read_csv("../ML projects/datasets/iris_data.csv")

# %% [markdown]
# #### displaying the first top five 5 rows of the dataframe

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ### to see the five last rows of the dataset

# %%
data.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %% [markdown]
# #### filtering features based on

# %%
num_val = [feature for feature in data.columns  if data[feature].dtype!='O']

print(num_val)
# Out:
# ['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']

# %% [markdown]
# #### to check how many rows and columns are there

# %%
data.shape
# Out:
# (150, 6)

# %% [markdown]
# #### to see the metadata or information of the dataset such as datatype,null counts , memory usage , and list of columns

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# #### to check the statistical distribution of the dataset min , max , mean , count, percentile of each column

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# ### to check null values in each column

# %%
data.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# ### to check the number of unique classes

# %%
data['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# ### to check the total number in each class

# %%
data['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# ### to remove all dublicate rows (keeep first)
#        data.drop_duplicates()
# ### to remove duplicates based on columns
#         data.drop_duplicates(subset=['col name'])
# ### to remove all duplicates (keep none)
#         data.duplicates(keep =False)
# ### to remove duplicates based on columns but keep first
#         data.drop_duplicates(subset=['col name'], keep='first')

# %%
data.drop_duplicates(subset=['Id'],keep='first')
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data.drop_duplicates()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# #### to sort dataset based on columns in ascemding order

# %%
data.sort_values(by='SepalLengthCm')
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 13    14            4.3           3.0            1.1           0.1
# 42    43            4.4           3.2            1.3           0.2
# 38    39            4.4           3.0            1.3           0.2
# 8      9            4.4           2.9            1.4           0.2
# 41    42            4.5           2.3            1.3           0.3
# ..   ...            ...           ...            ...           ...
# 122  123            7.7           2.8            6.7           2.0
# 118  119            7.7           2.6            6.9           2.3
# 117  118            7.7           3.8            6.7           2.2
# 135  136            7.7           3.0            6.1           2.3
# 131  132            7.9           3.8            6.4           2.0
#
#             Species
# 13      Iris-setosa
# 42      Iris-setosa
# 38      Iris-setosa
# 8       Iris-setosa
# 41      Iris-setosa
# ..              ...
# ...

# %% [markdown]
# ### to sort dataset based on column in descending order

# %%
data.sort_values(by='SepalLengthCm',ascending=False)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 131  132            7.9           3.8            6.4           2.0
# 135  136            7.7           3.0            6.1           2.3
# 122  123            7.7           2.8            6.7           2.0
# 117  118            7.7           3.8            6.7           2.2
# 118  119            7.7           2.6            6.9           2.3
# ..   ...            ...           ...            ...           ...
# 41    42            4.5           2.3            1.3           0.3
# 42    43            4.4           3.2            1.3           0.2
# 38    39            4.4           3.0            1.3           0.2
# 8      9            4.4           2.9            1.4           0.2
# 13    14            4.3           3.0            1.1           0.1
#
#             Species
# 131  Iris-virginica
# 135  Iris-virginica
# 122  Iris-virginica
# 117  Iris-virginica
# 118  Iris-virginica
# ..              ...
# ...

# %% [markdown]
# ### To sort the datset based on multiple columns in ascending order

# %%
data.sort_values(by=['SepalLengthCm','SepalWidthCm'])
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 13    14            4.3           3.0            1.1           0.1
# 8      9            4.4           2.9            1.4           0.2
# 38    39            4.4           3.0            1.3           0.2
# 42    43            4.4           3.2            1.3           0.2
# 41    42            4.5           2.3            1.3           0.3
# ..   ...            ...           ...            ...           ...
# 118  119            7.7           2.6            6.9           2.3
# 122  123            7.7           2.8            6.7           2.0
# 135  136            7.7           3.0            6.1           2.3
# 117  118            7.7           3.8            6.7           2.2
# 131  132            7.9           3.8            6.4           2.0
#
#             Species
# 13      Iris-setosa
# 8       Iris-setosa
# 38      Iris-setosa
# 42      Iris-setosa
# 41      Iris-setosa
# ..              ...
# ...

# %% [markdown]
# ### sort by index in ascending

# %%
data.sort_index()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# ### sort by index in descending order

# %%
data.sort_index(ascending=False)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 149  150            5.9           3.0            5.1           1.8
# 148  149            6.2           3.4            5.4           2.3
# 147  148            6.5           3.0            5.2           2.0
# 146  147            6.3           2.5            5.0           1.9
# 145  146            6.7           3.0            5.2           2.3
# ..   ...            ...           ...            ...           ...
# 4      5            5.0           3.6            1.4           0.2
# 3      4            4.6           3.1            1.5           0.2
# 2      3            4.7           3.2            1.3           0.2
# 1      2            4.9           3.0            1.4           0.2
# 0      1            5.1           3.5            1.4           0.2
#
#             Species
# 149  Iris-virginica
# 148  Iris-virginica
# 147  Iris-virginica
# 146  Iris-virginica
# 145  Iris-virginica
# ..              ...
# ...

# %% [markdown]
# ### to move NaN values to top

# %%
data.sort_values(by = ['SepalLengthCm'],na_position='first')
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 13    14            4.3           3.0            1.1           0.1
# 42    43            4.4           3.2            1.3           0.2
# 38    39            4.4           3.0            1.3           0.2
# 8      9            4.4           2.9            1.4           0.2
# 41    42            4.5           2.3            1.3           0.3
# ..   ...            ...           ...            ...           ...
# 122  123            7.7           2.8            6.7           2.0
# 118  119            7.7           2.6            6.9           2.3
# 117  118            7.7           3.8            6.7           2.2
# 135  136            7.7           3.0            6.1           2.3
# 131  132            7.9           3.8            6.4           2.0
#
#             Species
# 13      Iris-setosa
# 42      Iris-setosa
# 38      Iris-setosa
# 8       Iris-setosa
# 41      Iris-setosa
# ..              ...
# ...

# %% [markdown]
# ### Apply lambda function
# let say if we want to add 20 for each values of SepalLengthCm , we use lambda function

# %%
data['SepalLengthCm'].apply(lambda x:x+30)
# Out:
# 0      35.1
# 1      34.9
# 2      34.7
# 3      34.6
# 4      35.0
#        ...
# 145    36.7
# 146    36.3
# 147    36.5
# 148    36.2
# 149    35.9
# Name: SepalLengthCm, Length: 150, dtype: float64

# %% [markdown]
# ### Matplotlib
# used for creating plots and visualizations (static,interactive and animated visualizations)

# %%
plt.figure(figsize=(6,6))
sns.countplot(data = data,x = data['Species'],hue='Species')
plt.show()
